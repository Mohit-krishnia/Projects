# %%
import pandas as pd

# %%
df=pd.read_csv('covid.txt',sep=',')
df
# Out:
#      iso_code continent     location      date  total_cases  new_cases  \
# 0         AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1         AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2         AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3         AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4         AFG      Asia  Afghanistan  04/01/20          NaN        0.0
# ...       ...       ...          ...       ...          ...        ...
# 4254      BGD      Asia   Bangladesh  19/03/20         10.0        2.0
# 4255      BGD      Asia   Bangladesh  20/03/20         10.0        0.0
# 4256      BGD      Asia   Bangladesh  21/03/20         17.0        7.0
# 4257      BGD      Asia   Bangladesh  22/03/20         24.0        7.0
# 4258      BGD      Asia   Bangladesh  23/03/20         27.0        3.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                    NaN           NaN         0.0                  NaN  ...
# 1                    NaN           NaN         0.0                  NaN  ...
# 2                    NaN           NaN         0.0                  NaN  ...
# 3                    NaN           NaN         0.0                  NaN  ...
# 4                    NaN           NaN         0.0                  NaN  ...
# ...                  ...           ...         ...                  ...  ...
# 4254               1.000           NaN         0.0                0.000  ...
# 4255               1.000           NaN         0.0                0.000  ...
# 4256               2.000           NaN         0.0                0.000  ...
# 4257               3.000           2.0         2.0                0.286  ...
# 4258               3.429           3.0         1.0                0.429  ...
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0           1803.987              NaN                597.029
# 1           1803.987              NaN                597.029
# 2           1803.987              NaN                597.029
# 3           1803.987              NaN                597.029
# 4           1803.987              NaN                597.029
# ...              ...              ...                    ...
# 4254        3523.984             14.8                298.003
# 4255        3523.984             14.8                298.003
# 4256        3523.984             14.8                298.003
# 4257        3523.984             14.8                298.003
# 4258             NaN              NaN                    NaN
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 0                    9.59             NaN           NaN
# 1                    9.59             NaN           NaN
# 2                    9.59             NaN           NaN
# 3                    9.59             NaN           NaN
# 4                    9.59             NaN           NaN
# ...                   ...             ...           ...
# 4254                 8.38             1.0          44.7
# 4255                 8.38             1.0          44.7
# 4256                 8.38             1.0          44.7
# 4257                 8.38             1.0          44.7
# 4258                  NaN             NaN           NaN
#
#       handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     37.746                         0.5            64.83
# 1                     37.746                         0.5            64.83
# 2                     37.746                         0.5            64.83
# 3                     37.746                         0.5            64.83
# 4                     37.746                         0.5            64.83
# ...                      ...                         ...              ...
# 4254                  34.808                         0.8            72.59
# 4255                  34.808                         0.8            72.59
# 4256                  34.808                         0.8            72.59
# 4257                  34.808                         0.8            72.59
# 4258                     NaN                         NaN              NaN
#
#       human_development_index
# 0                       0.498
# 1                       0.498
# 2                       0.498
# 3                       0.498
# 4                       0.498
# ...                       ...
# 4254                    0.608
# 4255                    0.608
# 4256                    0.608
# 4257                    0.608
# 4258                      NaN
#
# [4259 rows x 49 columns]

# %%
# Find no. of rows & columns in the dataset
df.shape
# Out:
# (4259, 49)

# %%
# Data types of columns
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# hosp_patients_per_million             float64
# weekly_icu_admissions                 float64
# weekly_icu_admissions_per_million     float64
# weekly_hosp_admissions                float64
# weekly_hosp_admissions_per_million    float64
# total_tests                           float64
# new_tests                             float64
# total_tests_per_thousand              float64
# new_tests_per_thousand                float64
# new_tests_smoothed                    float64
# new_tests_smoothed_per_thousand       float64
# tests_per_case                        float64
# positive_rate                         float64
# stringency_index                      float64
# population                            float64
# population_density                    float64
# median_age                            float64
# aged_65_older                         float64
# aged_70_older                         float64
# gdp_per_capita                        float64
# extreme_poverty                       float64
# cardiovasc_death_rate                 float64
# diabetes_prevalence                   float64
# female_smokers                        float64
# male_smokers                          float64
# handwashing_facilities                float64
# hospital_beds_per_thousand            float64
# life_expectancy                       float64
# human_development_index               float64
# dtype: object

# %%
# Info & describe of data in dataframe
df.describe(include='all')
# Out:
#        iso_code continent     location      date   total_cases     new_cases  \
# count      4259      4259         4259      4259  3.831000e+03   4202.000000
# unique       16         6           16       323           NaN           NaN
# top         AFG      Asia  Afghanistan  09/06/20           NaN           NaN
# freq        323      1313          323        15           NaN           NaN
# mean        NaN       NaN          NaN       NaN  3.476105e+04    477.557354
# std         NaN       NaN          NaN       NaN  1.310949e+05   1825.468525
# min         NaN       NaN          NaN       NaN  1.000000e+00      0.000000
# 25%         NaN       NaN          NaN       NaN  1.110000e+02      0.000000
# 50%         NaN       NaN          NaN       NaN  4.074000e+03     33.000000
# 75%         NaN       NaN          NaN       NaN  2.700800e+04    193.000000
# max         NaN       NaN          NaN       NaN  1.318371e+06  18326.000000
#
#         new_cases_smoothed  total_deaths   new_deaths  new_deaths_smoothed  \
# count          4175.000000   3368.000000  4202.000000          4175.000000
# unique                 NaN           NaN          NaN                  NaN
# top                    NaN           NaN          NaN                  NaN
# freq                   NaN           NaN          NaN                  NaN
# mean            466.318499    914.066211    11.078296            10.873892
# std            1770.627882   3582.026204    69.807603            52.994410
# min               0.000000      1.000000     0.000000             0.000000
# 25%               0.714000     16.000000     0.000000             0.000000
# 50%              41.000000    108.500000     0.000000             0.571000
# 75%             191.857000    678.000000     4.000000             3.714000
# max           15051.143000  35727.000000  3351.000000           788.857000
#
#         ...  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count   ...     3767.000000      1824.000000            3777.000000
# unique  ...             NaN              NaN                    NaN
# top     ...             NaN              NaN                    NaN
# freq    ...             NaN              NaN                    NaN
# mean    ...    22908.730704         1.020121             274.195820
# std     ...    15133.980634         1.526718             155.768512
# min     ...     1803.987000         0.500000             107.791000
# 25%     ...    11803.431000         0.500000             151.689000
# 50%     ...    18933.907000         0.700000             235.954000
# 75%     ...    43290.705000         1.100000             341.010000
# max     ...    45436.686000        14.800000             597.029000
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# count           4022.000000     2970.000000   2970.000000
# unique                  NaN             NaN           NaN
# top                     NaN             NaN           NaN
# freq                    NaN             NaN           NaN
# mean               8.774667       10.171919     34.852660
# std                3.507761       10.331798     11.224477
# min                3.940000        0.300000     16.500000
# 25%                6.350000        1.500000     27.700000
# 50%                7.110000        5.800000     37.600000
# 75%               11.620000       16.200000     42.500000
# max               16.520000       29.000000     52.100000
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count              1553.000000                 3281.000000      4258.000000
# unique                     NaN                         NaN              NaN
# top                        NaN                         NaN              NaN
# freq                       NaN                         NaN              NaN
# mean                 66.725832                    3.532670        76.086740
# std                  26.635631                    1.821809         5.973965
# min                  26.664000                    0.500000        61.150000
# 25%                  37.746000                    2.000000        73.920000
# 50%                  83.241000                    3.800000        76.880000
# 75%                  83.741000                    4.700000        81.540000
# max                  94.043000                    7.370000        83.730000
#
#         human_development_index
# count               3777.000000
# unique                      NaN
# top                         NaN
# freq                        NaN
# mean                   0.776563
# std                    0.119022
# min                    0.498000
# 25%                    0.755000
# 50%                    0.785000
# 75%                    0.846000
# max                    0.939000
#
# [11 rows x 49 columns]

# %%
# Find count of unique values in location column
df['location'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh'], dtype=object)

# %%
# Find which continent has maximum frequency using values counts
df['continent'].value_counts()
# Out:
# Asia             1313
# North America     969
# Europe            832
# Africa            564
# Oceania           323
# South America     258
# Name: continent, dtype: int64

# %%
# Find maximum & mean value in 'total_cases'
df['total_cases'].max()
df['total_cases'].mean()
# Out:
# 34761.04724614983

# %%
# Find 25%,50% & 75% quartile value in 'total_deaths'
print("25% of total deaths is : ",df['total_cases'].quantile(.25))
print("50% of total deaths is : ",df['total_cases'].quantile(.50))
print("75% of total deaths is : ",df['total_cases'].quantile(.75))
# Out:
# 25% of total deaths is :  111.0
# 50% of total deaths is :  4074.0
# 75% of total deaths is :  27008.0

# %%
#  Find which continent has maximum 'human_development_index'
idx = df.groupby(by=['continent'])['human_development_index'].max()
idx.sort_values(ascending=False)
# Out:
# continent
# Oceania          0.939
# Europe           0.908
# Asia             0.846
# South America    0.825
# North America    0.807
# Africa           0.754
# Name: human_development_index, dtype: float64

# %%
# Find which continent has minimum 'gdp_per_capita'.
idx=df.groupby(by=['continent'])['gdp_per_capita'].min()
idx.sort_values(ascending=True)
# Out:
# continent
# Asia              1803.987
# Africa            5819.495
# Europe           11803.431
# South America    18933.907
# North America    21490.943
# Oceania          44648.710
# Name: gdp_per_capita, dtype: float64

# %%
''# # Filter the dataframe with only this columns['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']
df_1=df.filter(['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])
df.update(df_1)
df_1
# df1=df.groupby(by='continent')['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']
# df.update(df1)
# df1.head()
# Out:
#      continent     location      date  total_cases  total_deaths  \
# 0         Asia  Afghanistan  31/12/19          NaN           NaN
# 1         Asia  Afghanistan  01/01/20          NaN           NaN
# 2         Asia  Afghanistan  02/01/20          NaN           NaN
# 3         Asia  Afghanistan  03/01/20          NaN           NaN
# 4         Asia  Afghanistan  04/01/20          NaN           NaN
# ...        ...          ...       ...          ...           ...
# 4254      Asia   Bangladesh  19/03/20         10.0           NaN
# 4255      Asia   Bangladesh  20/03/20         10.0           NaN
# 4256      Asia   Bangladesh  21/03/20         17.0           NaN
# 4257      Asia   Bangladesh  22/03/20         24.0           2.0
# 4258      Asia   Bangladesh  23/03/20         27.0           3.0
#
#       gdp_per_capita  human_development_index
# 0           1803.987                    0.498
# 1           1803.987                    0.498
# 2           1803.987                    0.498
# 3           1803.987                    0.498
# 4           1803.987                    0.498
# ...              ...                      ...
# 4254        3523.984                    0.608
# 4255        3523.984                    0.608
# 4256        3523.984                    0.608
# 4257        3523.984                    0.608
# 4258             NaN                      NaN
#
# [4259 rows x 7 columns]

# %%
df1=df.groupby(by='continent')['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']
df.update(df1)
df1.head()
# Out:
# C:\Users\mohit\AppData\Local\Temp/ipykernel_20428/4097551089.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1=df.groupby(by='continent')['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']
#           continent     location      date  total_cases  total_deaths  \
# 0              Asia  Afghanistan  31/12/19          NaN           NaN
# 1              Asia  Afghanistan  01/01/20          NaN           NaN
# 2              Asia  Afghanistan  02/01/20          NaN           NaN
# 3              Asia  Afghanistan  03/01/20          NaN           NaN
# 4              Asia  Afghanistan  04/01/20          NaN           NaN
# 323          Europe      Albania  09/03/20          2.0           NaN
# 324          Europe      Albania  10/03/20          6.0           NaN
# 325          Europe      Albania  11/03/20         10.0           NaN
# 326          Europe      Albania  12/03/20         11.0           1.0
# 327          Europe      Albania  13/03/20         23.0           1.0
# 577          Africa      Algeria  31/12/19          NaN           NaN
# 578          Africa      Algeria  01/01/20          NaN           NaN
# 579          Africa      Algeria  02/01/20          NaN           NaN
# 580          Africa      Algeria  03/01/20          NaN           NaN
# 581          Africa      Algeria  04/01/20          NaN           NaN
# 1396  North America     Anguilla  27/03/20          2.0           NaN
# 1397  North America     Anguilla  28/03/20          2.0           NaN
# 1398  North America     Anguilla  29/03/20          2.0           NaN
# 1399  North America     Anguilla  30/03/20          2.0           NaN
# 1400  North America     Anguilla  31/03/20          2.0           NaN
# 1875  South America    Argentina  04/03/20          1.0           NaN
# 1876  South America    Argentina  06/03/20          2.0           NaN
# 1877  South America    Argentina  07/03/20          8.0           NaN
# 1878  South America    Argentina  08/03/20          9.0           1.0
# 1879  South America    Argentina  09/03/20         12.0           1.0
# 2701        Oceania    Australia  31/12/19          NaN           NaN
# 2702        Oceania    Australia  01/01/20          NaN           NaN
# 2703        Oceania    Australia  02/01/20          NaN           NaN
# 2704        Oceania    Australia  03/01/20          NaN           NaN
# 2705        Oceania    Australia  04/01/20          NaN           NaN
#
#       gdp_per_capita  human_development_index
# 0           1803.987                    0.498
# 1           1803.987                    0.498
# 2           1803.987                    0.498
# 3           1803.987                    0.498
# 4           1803.987                    0.498
# 323        11803.431                    0.785
# 324        11803.431                    0.785
# 325        11803.431                    0.785
# 326        11803.431                    0.785
# 327        11803.431                    0.785
# 577        13913.839                    0.754
# 578        13913.839                    0.754
# 579        13913.839                    0.754
# 580        13913.839                    0.754
# 581        13913.839                    0.754
# 1396             NaN                      NaN
# 1397             NaN                      NaN
# 1398             NaN                      NaN
# 1399             NaN                      NaN
# 1400             NaN                      NaN
# 1875       18933.907                    0.825
# 1876       18933.907                    0.825
# 1877       18933.907                    0.825
# 1878       18933.907                    0.825
# 1879       18933.907                    0.825
# 2701       44648.710                    0.939
# 2702       44648.710                    0.939
# 2703       44648.710                    0.939
# 2704       44648.710                    0.939
# 2705       44648.710                    0.939

# %%
#  Remove all duplicates observations
df.drop_duplicates()
# Out:
#      iso_code continent     location      date  total_cases  new_cases  \
# 0         AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1         AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2         AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3         AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4         AFG      Asia  Afghanistan  04/01/20          NaN        0.0
# ...       ...       ...          ...       ...          ...        ...
# 4254      BGD      Asia   Bangladesh  19/03/20         10.0        2.0
# 4255      BGD      Asia   Bangladesh  20/03/20         10.0        0.0
# 4256      BGD      Asia   Bangladesh  21/03/20         17.0        7.0
# 4257      BGD      Asia   Bangladesh  22/03/20         24.0        7.0
# 4258      BGD      Asia   Bangladesh  23/03/20         27.0        3.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                    NaN           NaN         0.0                  NaN  ...
# 1                    NaN           NaN         0.0                  NaN  ...
# 2                    NaN           NaN         0.0                  NaN  ...
# 3                    NaN           NaN         0.0                  NaN  ...
# 4                    NaN           NaN         0.0                  NaN  ...
# ...                  ...           ...         ...                  ...  ...
# 4254               1.000           NaN         0.0                0.000  ...
# 4255               1.000           NaN         0.0                0.000  ...
# 4256               2.000           NaN         0.0                0.000  ...
# 4257               3.000           2.0         2.0                0.286  ...
# 4258               3.429           3.0         1.0                0.429  ...
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0           1803.987              NaN                597.029
# 1           1803.987              NaN                597.029
# 2           1803.987              NaN                597.029
# 3           1803.987              NaN                597.029
# 4           1803.987              NaN                597.029
# ...              ...              ...                    ...
# 4254        3523.984             14.8                298.003
# 4255        3523.984             14.8                298.003
# 4256        3523.984             14.8                298.003
# 4257        3523.984             14.8                298.003
# 4258             NaN              NaN                    NaN
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 0                    9.59             NaN           NaN
# 1                    9.59             NaN           NaN
# 2                    9.59             NaN           NaN
# 3                    9.59             NaN           NaN
# 4                    9.59             NaN           NaN
# ...                   ...             ...           ...
# 4254                 8.38             1.0          44.7
# 4255                 8.38             1.0          44.7
# 4256                 8.38             1.0          44.7
# 4257                 8.38             1.0          44.7
# 4258                  NaN             NaN           NaN
#
#       handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     37.746                         0.5            64.83
# 1                     37.746                         0.5            64.83
# 2                     37.746                         0.5            64.83
# 3                     37.746                         0.5            64.83
# 4                     37.746                         0.5            64.83
# ...                      ...                         ...              ...
# 4254                  34.808                         0.8            72.59
# 4255                  34.808                         0.8            72.59
# 4256                  34.808                         0.8            72.59
# 4257                  34.808                         0.8            72.59
# 4258                     NaN                         NaN              NaN
#
#       human_development_index
# 0                       0.498
# 1                       0.498
# 2                       0.498
# 3                       0.498
# 4                       0.498
# ...                       ...
# 4254                    0.608
# 4255                    0.608
# 4256                    0.608
# 4257                    0.608
# 4258                      NaN
#
# [4259 rows x 49 columns]

# %%
# . Find missing values in all columns
df.isnull().sum()
# Out:
# iso_code                                 0
# continent                                0
# location                                 0
# date                                     0
# total_cases                            428
# new_cases                               57
# new_cases_smoothed                      84
# total_deaths                           891
# new_deaths                              57
# new_deaths_smoothed                     84
# total_cases_per_million                428
# new_cases_per_million                   57
# new_cases_smoothed_per_million          84
# total_deaths_per_million               891
# new_deaths_per_million                  57
# new_deaths_smoothed_per_million         84
# reproduction_rate                     1566
# icu_patients                          4037
# icu_patients_per_million              4037
# hosp_patients                         4037
# hosp_patients_per_million             4037
# weekly_icu_admissions                 4259
# weekly_icu_admissions_per_million     4259
# weekly_hosp_admissions                4259
# weekly_hosp_admissions_per_million    4259
# total_tests                           3569
# new_tests                             3629
# total_tests_per_thousand              3569
# new_tests_per_thousand                3629
# new_tests_smoothed                    3505
# new_tests_smoothed_per_thousand       3505
# tests_per_case                        3513
# positive_rate                         3512
# stringency_index                       943
# population                               1
# population_density                     237
# median_age                             492
# aged_65_older                          492
# aged_70_older                          492
# gdp_per_capita                         492
# extreme_poverty                       2435
# cardiovasc_death_rate                  482
# diabetes_prevalence                    237
# female_smokers                        1289
# male_smokers                          1289
# handwashing_facilities                2706
# hospital_beds_per_thousand             978
# life_expectancy                          1
# human_development_index                482
# dtype: int64

# %%
#  Remove all observations where continent column value is missing
df.dropna(subset=['continent'], inplace=True)

# %%
# Fill all missing values with 0
df.fillna(0)
# Out:
#      iso_code continent     location      date  total_cases  new_cases  \
# 0         AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1         AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2         AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3         AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4         AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...       ...       ...          ...       ...          ...        ...
# 4254      BGD      Asia   Bangladesh  19/03/20         10.0        2.0
# 4255      BGD      Asia   Bangladesh  20/03/20         10.0        0.0
# 4256      BGD      Asia   Bangladesh  21/03/20         17.0        7.0
# 4257      BGD      Asia   Bangladesh  22/03/20         24.0        7.0
# 4258      BGD      Asia   Bangladesh  23/03/20         27.0        3.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                  0.000           0.0         0.0                0.000  ...
# 1                  0.000           0.0         0.0                0.000  ...
# 2                  0.000           0.0         0.0                0.000  ...
# 3                  0.000           0.0         0.0                0.000  ...
# 4                  0.000           0.0         0.0                0.000  ...
# ...                  ...           ...         ...                  ...  ...
# 4254               1.000           0.0         0.0                0.000  ...
# 4255               1.000           0.0         0.0                0.000  ...
# 4256               2.000           0.0         0.0                0.000  ...
# 4257               3.000           2.0         2.0                0.286  ...
# 4258               3.429           3.0         1.0                0.429  ...
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0           1803.987              0.0                597.029
# 1           1803.987              0.0                597.029
# 2           1803.987              0.0                597.029
# 3           1803.987              0.0                597.029
# 4           1803.987              0.0                597.029
# ...              ...              ...                    ...
# 4254        3523.984             14.8                298.003
# 4255        3523.984             14.8                298.003
# 4256        3523.984             14.8                298.003
# 4257        3523.984             14.8                298.003
# 4258           0.000              0.0                  0.000
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 0                    9.59             0.0           0.0
# 1                    9.59             0.0           0.0
# 2                    9.59             0.0           0.0
# 3                    9.59             0.0           0.0
# 4                    9.59             0.0           0.0
# ...                   ...             ...           ...
# 4254                 8.38             1.0          44.7
# 4255                 8.38             1.0          44.7
# 4256                 8.38             1.0          44.7
# 4257                 8.38             1.0          44.7
# 4258                 0.00             0.0           0.0
#
#       handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     37.746                         0.5            64.83
# 1                     37.746                         0.5            64.83
# 2                     37.746                         0.5            64.83
# 3                     37.746                         0.5            64.83
# 4                     37.746                         0.5            64.83
# ...                      ...                         ...              ...
# 4254                  34.808                         0.8            72.59
# 4255                  34.808                         0.8            72.59
# 4256                  34.808                         0.8            72.59
# 4257                  34.808                         0.8            72.59
# 4258                   0.000                         0.0             0.00
#
#       human_development_index
# 0                       0.498
# 1                       0.498
# 2                       0.498
# 3                       0.498
# 4                       0.498
# ...                       ...
# 4254                    0.608
# 4255                    0.608
# 4256                    0.608
# 4257                    0.608
# 4258                    0.000
#
# [4259 rows x 49 columns]

# %%
# Convert date column in datetime format using pandas.to_datetime
df['date']=pd.to_datetime(df['date']).dt.date
df
# Out:
#      iso_code continent     location        date  total_cases  new_cases  \
# 0         AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1         AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2         AFG      Asia  Afghanistan  2020-02-01          NaN        0.0
# 3         AFG      Asia  Afghanistan  2020-03-01          NaN        0.0
# 4         AFG      Asia  Afghanistan  2020-04-01          NaN        0.0
# ...       ...       ...          ...         ...          ...        ...
# 4254      BGD      Asia   Bangladesh  2020-03-19         10.0        2.0
# 4255      BGD      Asia   Bangladesh  2020-03-20         10.0        0.0
# 4256      BGD      Asia   Bangladesh  2020-03-21         17.0        7.0
# 4257      BGD      Asia   Bangladesh  2020-03-22         24.0        7.0
# 4258      BGD      Asia   Bangladesh  2020-03-23         27.0        3.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                    NaN           NaN         0.0                  NaN  ...
# 1                    NaN           NaN         0.0                  NaN  ...
# 2                    NaN           NaN         0.0                  NaN  ...
# 3                    NaN           NaN         0.0                  NaN  ...
# 4                    NaN           NaN         0.0                  NaN  ...
# ...                  ...           ...         ...                  ...  ...
# 4254               1.000           NaN         0.0                0.000  ...
# 4255               1.000           NaN         0.0                0.000  ...
# 4256               2.000           NaN         0.0                0.000  ...
# 4257               3.000           2.0         2.0                0.286  ...
# 4258               3.429           3.0         1.0                0.429  ...
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0           1803.987              NaN                597.029
# 1           1803.987              NaN                597.029
# 2           1803.987              NaN                597.029
# 3           1803.987              NaN                597.029
# 4           1803.987              NaN                597.029
# ...              ...              ...                    ...
# 4254        3523.984             14.8                298.003
# 4255        3523.984             14.8                298.003
# 4256        3523.984             14.8                298.003
# 4257        3523.984             14.8                298.003
# 4258             NaN              NaN                    NaN
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 0                    9.59             NaN           NaN
# 1                    9.59             NaN           NaN
# 2                    9.59             NaN           NaN
# 3                    9.59             NaN           NaN
# 4                    9.59             NaN           NaN
# ...                   ...             ...           ...
# 4254                 8.38             1.0          44.7
# 4255                 8.38             1.0          44.7
# 4256                 8.38             1.0          44.7
# 4257                 8.38             1.0          44.7
# 4258                  NaN             NaN           NaN
#
#       handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     37.746                         0.5            64.83
# 1                     37.746                         0.5            64.83
# 2                     37.746                         0.5            64.83
# 3                     37.746                         0.5            64.83
# 4                     37.746                         0.5            64.83
# ...                      ...                         ...              ...
# 4254                  34.808                         0.8            72.59
# 4255                  34.808                         0.8            72.59
# 4256                  34.808                         0.8            72.59
# 4257                  34.808                         0.8            72.59
# 4258                     NaN                         NaN              NaN
#
#       human_development_index
# 0                       0.498
# 1                       0.498
# 2                       0.498
# 3                       0.498
# 4                       0.498
# ...                       ...
# 4254                    0.608
# 4255                    0.608
# 4256                    0.608
# 4257                    0.608
# 4258                      NaN
#
# [4259 rows x 49 columns]

# %%
# Create new column month after extracting month data from date column
df['month']=pd.to_datetime(df['date']).dt.month
df
# Out:
#      iso_code continent     location        date  total_cases  new_cases  \
# 0         AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1         AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2         AFG      Asia  Afghanistan  2020-02-01          NaN        0.0
# 3         AFG      Asia  Afghanistan  2020-03-01          NaN        0.0
# 4         AFG      Asia  Afghanistan  2020-04-01          NaN        0.0
# ...       ...       ...          ...         ...          ...        ...
# 4254      BGD      Asia   Bangladesh  2020-03-19         10.0        2.0
# 4255      BGD      Asia   Bangladesh  2020-03-20         10.0        0.0
# 4256      BGD      Asia   Bangladesh  2020-03-21         17.0        7.0
# 4257      BGD      Asia   Bangladesh  2020-03-22         24.0        7.0
# 4258      BGD      Asia   Bangladesh  2020-03-23         27.0        3.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                    NaN           NaN         0.0                  NaN  ...
# 1                    NaN           NaN         0.0                  NaN  ...
# 2                    NaN           NaN         0.0                  NaN  ...
# 3                    NaN           NaN         0.0                  NaN  ...
# 4                    NaN           NaN         0.0                  NaN  ...
# ...                  ...           ...         ...                  ...  ...
# 4254               1.000           NaN         0.0                0.000  ...
# 4255               1.000           NaN         0.0                0.000  ...
# 4256               2.000           NaN         0.0                0.000  ...
# 4257               3.000           2.0         2.0                0.286  ...
# 4258               3.429           3.0         1.0                0.429  ...
#
#       extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                 NaN                597.029                 9.59
# 1                 NaN                597.029                 9.59
# 2                 NaN                597.029                 9.59
# 3                 NaN                597.029                 9.59
# 4                 NaN                597.029                 9.59
# ...               ...                    ...                  ...
# 4254             14.8                298.003                 8.38
# 4255             14.8                298.003                 8.38
# 4256             14.8                298.003                 8.38
# 4257             14.8                298.003                 8.38
# 4258              NaN                    NaN                  NaN
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 0                NaN           NaN                  37.746
# 1                NaN           NaN                  37.746
# 2                NaN           NaN                  37.746
# 3                NaN           NaN                  37.746
# 4                NaN           NaN                  37.746
# ...              ...           ...                     ...
# 4254             1.0          44.7                  34.808
# 4255             1.0          44.7                  34.808
# 4256             1.0          44.7                  34.808
# 4257             1.0          44.7                  34.808
# 4258             NaN           NaN                     NaN
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                            0.5            64.83                    0.498
# 1                            0.5            64.83                    0.498
# 2                            0.5            64.83                    0.498
# 3                            0.5            64.83                    0.498
# 4                            0.5            64.83                    0.498
# ...                          ...              ...                      ...
# 4254                         0.8            72.59                    0.608
# 4255                         0.8            72.59                    0.608
# 4256                         0.8            72.59                    0.608
# 4257                         0.8            72.59                    0.608
# 4258                         NaN              NaN                      NaN
#
#       month
# 0        12
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 4254      3
# 4255      3
# 4256      3
# 4257      3
# 4258      3
#
# [4259 rows x 50 columns]

# %%
#. Find max value in all columns using groupby function on 'continent' column
df_1=df.groupby(by=['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])['continent'].size().sort_values(ascending=True).reset_index(name='find_max')
df_1
# Out:
#           continent    location        date  total_cases  total_deaths  \
# 0            Africa     Algeria  2020-01-04        716.0          44.0
# 1            Europe     Austria  2020-11-16     203494.0        1679.0
# 2            Europe     Austria  2020-11-17     207798.0        1741.0
# 3            Europe     Austria  2020-12-04      13807.0         337.0
# 4            Europe     Austria  2020-12-05      15874.0         620.0
# ...             ...         ...         ...          ...           ...
# 2910           Asia  Azerbaijan  2020-03-04        400.0           5.0
# 2911           Asia  Azerbaijan  2020-03-05       1894.0          25.0
# 2912           Asia  Azerbaijan  2020-03-06       5935.0          71.0
# 2913           Asia  Azerbaijan  2020-03-08      32443.0         462.0
# 2914  South America   Argentina  2020-12-11    1273342.0       34531.0
#
#       gdp_per_capita  human_development_index  find_max
# 0          13913.839                    0.754         1
# 1          45436.686                    0.908         1
# 2          45436.686                    0.908         1
# 3          45436.686                    0.908         1
# 4          45436.686                    0.908         1
# ...              ...                      ...       ...
# 2910       15847.419                    0.757         1
# 2911       15847.419                    0.757         1
# 2912       15847.419                    0.757         1
# 2913       15847.419                    0.757         1
# 2914       18933.907                    0.825         1
#
# [2915 rows x 8 columns]

# %%
# . Store the result in a new dataframe named 'df_groupby'
df_groupby=df_1
df_groupby
# Out:
#           continent    location        date  total_cases  total_deaths  \
# 0            Africa     Algeria  2020-01-04        716.0          44.0
# 1            Europe     Austria  2020-11-16     203494.0        1679.0
# 2            Europe     Austria  2020-11-17     207798.0        1741.0
# 3            Europe     Austria  2020-12-04      13807.0         337.0
# 4            Europe     Austria  2020-12-05      15874.0         620.0
# ...             ...         ...         ...          ...           ...
# 2910           Asia  Azerbaijan  2020-03-04        400.0           5.0
# 2911           Asia  Azerbaijan  2020-03-05       1894.0          25.0
# 2912           Asia  Azerbaijan  2020-03-06       5935.0          71.0
# 2913           Asia  Azerbaijan  2020-03-08      32443.0         462.0
# 2914  South America   Argentina  2020-12-11    1273342.0       34531.0
#
#       gdp_per_capita  human_development_index  find_max
# 0          13913.839                    0.754         1
# 1          45436.686                    0.908         1
# 2          45436.686                    0.908         1
# 3          45436.686                    0.908         1
# 4          45436.686                    0.908         1
# ...              ...                      ...       ...
# 2910       15847.419                    0.757         1
# 2911       15847.419                    0.757         1
# 2912       15847.419                    0.757         1
# 2913       15847.419                    0.757         1
# 2914       18933.907                    0.825         1
#
# [2915 rows x 8 columns]

# %%
#Create a new feature 'total_deaths_to_total_cases' by ratio of'total_deaths' column to 'total_cases'
df_groupby['total_deaths_to_total_cases']=df_groupby['total_deaths'].div(df_groupby['total_cases'])
df_groupby
# Out:
#           continent    location        date  total_cases  total_deaths  \
# 0            Africa     Algeria  2020-01-04        716.0          44.0
# 1            Europe     Austria  2020-11-16     203494.0        1679.0
# 2            Europe     Austria  2020-11-17     207798.0        1741.0
# 3            Europe     Austria  2020-12-04      13807.0         337.0
# 4            Europe     Austria  2020-12-05      15874.0         620.0
# ...             ...         ...         ...          ...           ...
# 2910           Asia  Azerbaijan  2020-03-04        400.0           5.0
# 2911           Asia  Azerbaijan  2020-03-05       1894.0          25.0
# 2912           Asia  Azerbaijan  2020-03-06       5935.0          71.0
# 2913           Asia  Azerbaijan  2020-03-08      32443.0         462.0
# 2914  South America   Argentina  2020-12-11    1273342.0       34531.0
#
#       gdp_per_capita  human_development_index  find_max  \
# 0          13913.839                    0.754         1
# 1          45436.686                    0.908         1
# 2          45436.686                    0.908         1
# 3          45436.686                    0.908         1
# 4          45436.686                    0.908         1
# ...              ...                      ...       ...
# 2910       15847.419                    0.757         1
# 2911       15847.419                    0.757         1
# 2912       15847.419                    0.757         1
# 2913       15847.419                    0.757         1
# 2914       18933.907                    0.825         1
#
#       total_deaths_to_total_cases
# 0                        0.061453
# 1                        0.008251
# 2                        0.008378
# 3                        0.024408
# 4                        0.039058
# ...                           ...
# 2910                     0.012500
# 2911                     0.013200
# 2912                     0.011963
# 2913                     0.014240
# 2914                     0.027118
#
# [2915 rows x 9 columns]

# %%
# Perform Univariate analysis on 'gdp_per_capita' column by plotting
import seaborn as sns
sns.distplot(df_groupby['gdp_per_capita'],kde=True,color='red')
# Out:
# D:\programs\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %%
# Plot a scatter plot of 'total_cases' & 'gdp_per_capita
sns.scatterplot(df_groupby['gdp_per_capita'],df_groupby['total_cases'],color='red')
# Out:
# D:\programs\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='total_cases'>

# %%
# Plot Pairplot on df_groupby dataset.
sns.pairplot(df_groupby)

# %%
# Plot a bar plot of 'continent' column with 'total_cases' 
sns.catplot(data=df_groupby,x='continent',y='total_cases',kind='bar')

# %%
# .Save the df_groupby dataframe in your local drive using pandas.to_csv function 
df_groupby.to_csv('Covid_Project.csv', index=False)
